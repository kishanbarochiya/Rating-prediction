# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
import requests
# Out:
# C:\Users\Kishan\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
url='https://www.flipkart.com/samsung-galaxy-f12-sky-blue-64-gb/product-reviews/itm0319ce24f74aa?pid=MOBGFG79BVGDHGWV&lid=LSTMOBGFG79BVGDHGWVGF2CRI&marketplace=FLIPKART&page=1'
driver1.get(url)
# Out:
# <ipython-input-2-15352917a91a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')

# %%
Ratings=[]
Reviews = []


for i in range(0,2000):
    pg='https://www.flipkart.com/samsung-galaxy-f12-sky-blue-64-gb/product-reviews/itm0319ce24f74aa?pid=MOBGFG79BVGDHGWV&lid=LSTMOBGFG79BVGDHGWVGF2CRI&marketplace=FLIPKART&page='+str(i)
    
    driver1.get(pg)
       
    time.sleep(3)
    
    rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    rating

    for i in rating:
        Rating = i.text
        Ratings.append(Rating)
    Ratings
    
    review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")
    review

    for i in review:
        Review = i.text
        Reviews.append(Review)
    Reviews
# Out:
# <ipython-input-3-efce5bc11c3c>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
# <ipython-input-3-efce5bc11c3c>:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-efce5bc11c3c> in <module>
#      10     time.sleep(3)
#      11
# ---> 12     rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
#      13     rating
#      14
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     541             stacklevel=2,
#     542         )
# ...

# %%
len(Ratings),len(Reviews)
# Out:
# (8500, 9628)

# %%
N = 8500
  
# printing original list
print("The original list is : " + str(Reviews))
  
# Get Top N elements from Records
# Using sorted() + lambda
res = sorted(Reviews, key = lambda x: x[1], reverse = True)[:N]
len(res)
# Out:
# The original list is : ['Best Samsung phone in this price range.Good battery back up.Decent Display.Fast fingerprint sensor.Rear camera quality is good.front camera is not up to the mark.90 Hz refresh rate is good.Good user interface.updated to one ui 3.1.there are some pre installed apps which can only be disabled.sound quality is low comparing with other smartphones in same price segment.using in low screen bightness noticed screen flickering.There is no screen protector or case in the box.Takes 160 minutes for ful...\nREAD MORE', "Amazing smartphone.\nCamera , battery back up , display , are awesome 👌.\nIt has a little bit heating problem but not at all .\nAmazing smartphone for students becoz I'm using as a student .😊😊.\nIt is heavy also , this is a bad point for this smartphone.\nBut all good . ND I'm satisfied .\nDelivery was also good 👍.\nThanks flipkart. 😊", 'This smartphone is very good in camera and battery\nAnd value for money from Samsung with clean and smooth\nUi and goo
# ...

# %%
len(res)
# Out:
# 8500

# %%
import pandas as pd
df = pd.DataFrame(list(zip(Ratings, res)),
               columns =['Rating', 'Comment'])
df
# Out:
#      Rating                                            Comment
# 0         4                         🤩🤩🤩 I am very very happy😊😊
# 1         4  👏👏 Delivery service is good 👍\nThis phone is a...
# 2         5                                     👌👌good control
# 3         4    👌👌👌Very good product I am very happy 👌👌👌 😊😊😊😊😊😊
# 4         5                                       💫✨Let it be✨
# ...     ...                                                ...
# 8495      5  Camera is very good and best is battery this p...
# 8496      4  Camera is not as per expectations,there is not...
# 8497      4  Camera Average 3/5\nPerformance Good 4/5\nDisp...
# 8498      4  Samsung f12 best build quality,heavy battery l...
# 8499      5  Camera is not good as campare to sumsung M20\n...
#
# [8500 rows x 2 columns]

# %%
df.to_csv('comment1.csv')

# %%
driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
url='https://www.flipkart.com/samsung-galaxy-f12-celestial-black-64-gb/product-reviews/itmaae10b8db3909?pid=MOBGFG79FUDPXZXQ&lid=LSTMOBGFG79FUDPXZXQH5PM6N&marketplace=FLIPKART&page=1'
driver1.get(url)
# Out:
# <ipython-input-2-415bd4a4ae65>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')

# %%
driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
url='https://www.flipkart.com/redmi-note-10t-5g-metallic-blue-64-gb/product-reviews/itm7a558068a9f23?pid=MOBGC7QFTGDSWQZN&lid=LSTMOBGC7QFTGDSWQZNA2WTPQ&marketplace=FLIPKART&page=1'
driver1.get(url)


Ratings=[]
Reviews = []


for i in range(0,16):
    pg='https://www.flipkart.com/redmi-note-10t-5g-metallic-blue-64-gb/product-reviews/itm7a558068a9f23?pid=MOBGC7QFTGDSWQZN&lid=LSTMOBGC7QFTGDSWQZNA2WTPQ&marketplace=FLIPKART&page='+str(i)
    
    driver1.get(pg)
       
    time.sleep(3)
    
    rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    rating

    for i in rating:
        Rating = i.text
        Ratings.append(Rating)
    Ratings
    
    review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")
    review

    for i in review:
        Review = i.text
        Reviews.append(Review)
    Reviews
# Out:
# <ipython-input-3-705a5b1f1428>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
# <ipython-input-3-705a5b1f1428>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
# <ipython-input-3-705a5b1f1428>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")

# %%
len(Reviews),len(Ratings)
# Out:
# (131, 120)

# %%
driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
url='https://www.flipkart.com/realme-c25y-glacier-blue-64-gb/product-reviews/itm14ec0239363bc?pid=MOBG7984SZDDBAZJ&lid=LSTMOBG7984SZDDBAZJ8RA0DA&marketplace=FLIPKART&page=1'
driver1.get(url)


for i in range(0,489):
    pg='https://www.flipkart.com/realme-c25y-glacier-blue-64-gb/product-reviews/itm14ec0239363bc?pid=MOBG7984SZDDBAZJ&lid=LSTMOBG7984SZDDBAZJ8RA0DA&marketplace=FLIPKART&page='+str(i)
    
    driver1.get(pg)
       
    time.sleep(3)
    
    rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    rating

    for i in rating:
        Rating = i.text
        Ratings.append(Rating)
    Ratings
    
    review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")
    review

    for i in review:
        Review = i.text
        Reviews.append(Review)
    Reviews
# Out:
# <ipython-input-5-8943278d2d04>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
# <ipython-input-5-8943278d2d04>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
# <ipython-input-5-8943278d2d04>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")

# %%
len(Reviews),len(Ratings)
# Out:
# (4809, 4076)

# %%
N = 4076
  
# printing original list
print("The original list is : " + str(Reviews))
  
# Get Top N elements from Records
# Using sorted() + lambda
res = sorted(Reviews, key = lambda x: x[1], reverse = True)[:N]
len(res)
# Out:
# The original list is : ['Phone good bt camera not good very wrost quality', 'Very good', 'excellent', "Miui dailer and contact has been replaced by Google dailer and contacts. Call recording option has been removed. It's no more a MI Phone.", 'Best compare to money', 'Super Nice', 'Price is high as per product', 'Very very very slow after updation', 'Good\nMy husband like this😄', 'Best phone in budget range.', 'Great battery power with lowest camera quality...', 'Now okk', 'Verry good mobile and proseser are verry High.। Thanks redmi', "It's the rebranded Poco C3 pro. It's tempered glass, back cover are exactly alike. Quality wise its amazing for the price. Definitely a value for money product.\nCamera quality is very good. Battery backup is also amazing. You get everything that you expect from a mid range phone. The power button is the finger print sensor.\nThe drawback that i found was that notification light is missing.", 'Not good piece', 'Mobile back side body all time vibrate d
# ...

# %%
import pandas as pd
df1 = pd.DataFrame(list(zip(Ratings, res)),
               columns =['Rating', 'Comment'])
df1

df1.to_csv('comment2.csv')

# %%
df1
# Out:
#      Rating                                            Comment
# 0         3               ✌️It's Mind Blowing Mobile 📲 Phone 😎
# 1         5                                        ♥️♥️♥️♥️ it
# 2         5                                                Nyc
# 3         5                                               Nycc
# 4         4                                                Nyc
# ...     ...                                                ...
# 4071      5                                          Very good
# 4072      5  Selfie camera is not good and real camera is good
# 4073      5  Best Budget Smart Phone.\nIn this price range ...
# 4074      5                Very bad quality screen not working
# 4075      5   Very good product but performance is average....
#
# [4076 rows x 2 columns]

# %%
driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
url='https://www.flipkart.com/motorola-g60-moonless-128-gb/product-reviews/itma894654fddb46?pid=MOBG9CJ6KRYW4NJT&lid=LSTMOBG9CJ6KRYW4NJTP2I8X0&marketplace=FLIPKART&page=1'
driver1.get(url)


for i in range(0,890):
    pg='https://www.flipkart.com/motorola-g60-moonless-128-gb/product-reviews/itma894654fddb46?pid=MOBG9CJ6KRYW4NJT&lid=LSTMOBG9CJ6KRYW4NJTP2I8X0&marketplace=FLIPKART&page='+str(i)
    
    driver1.get(pg)
       
    time.sleep(3)
    
    rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    rating

    for i in rating:
        Rating = i.text
        Ratings.append(Rating)
    Ratings
    
    review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")
    review

    for i in review:
        Review = i.text
        Reviews.append(Review)
    Reviews
# Out:
# <ipython-input-10-79cf56f152c5>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1=webdriver.Chrome('C:/Users/Kishan/Documents/chromedriver_win32/chromedriver.exe')
# <ipython-input-10-79cf56f152c5>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rating = driver1.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
# <ipython-input-10-79cf56f152c5>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review = driver1.find_elements_by_xpath("//div[@class='t-ZTKy']")

# %%
len(Reviews),len(Ratings)
# Out:
# (13680, 11394)

# %%
N = 11394
  
# printing original list
print("The original list is : " + str(Reviews))
  
# Get Top N elements from Records
# Using sorted() + lambda
res = sorted(Reviews, key = lambda x: x[1], reverse = True)[:N]
len(res)
# Out:
# The original list is : ['Phone good bt camera not good very wrost quality', 'Very good', 'excellent', "Miui dailer and contact has been replaced by Google dailer and contacts. Call recording option has been removed. It's no more a MI Phone.", 'Best compare to money', 'Super Nice', 'Price is high as per product', 'Very very very slow after updation', 'Good\nMy husband like this😄', 'Best phone in budget range.', 'Great battery power with lowest camera quality...', 'Now okk', 'Verry good mobile and proseser are verry High.। Thanks redmi', "It's the rebranded Poco C3 pro. It's tempered glass, back cover are exactly alike. Quality wise its amazing for the price. Definitely a value for money product.\nCamera quality is very good. Battery backup is also amazing. You get everything that you expect from a mid range phone. The power button is the finger print sensor.\nThe drawback that i found was that notification light is missing.", 'Not good piece', 'Mobile back side body all time vibrate d
# ...

# %%
import pandas as pd
df2 = pd.DataFrame(list(zip(Ratings, res)),
               columns =['Rating', 'Comment'])
df2

df2.to_csv('comment3.csv')

# %%
df2
# Out:
#       Rating                                            Comment
# 0          3                           🤟🤟🤟 Motorola is the best
# 1          5  🙋🙋HONEST REVIEW 🙋🙋\n1st...Camre click always n...
# 2          5  😱😱6000mah good luck with your friends👭👬 and th...
# 3          5  👍😘😘😘Wow very nice product "Motorola"(Moto G60 ...
# 4          4  🤩😍🥰❤❤❤ very nice phone.... people don't think ...
# ...      ...                                                ...
# 11389      5                 Best phone go ahead to buy it... 👍
# 11390      5                              Really Nice product..
# 11391      5                Really a great phone from motorola.
# 11392      5  Gets heated a lot. Camera choppy. Does not hav...
# 11393      5               Very nice phone in this price range.
#
# [11394 rows x 2 columns]

# %%
df1.shape , df2.shape
# Out:
# ((4076, 2), (11394, 2))

# %%
df1.head()
# Out:
#   Rating                               Comment
# 0      3  ✌️It's Mind Blowing Mobile 📲 Phone 😎
# 1      5                           ♥️♥️♥️♥️ it
# 2      5                                   Nyc
# 3      5                                  Nycc
# 4      4                                   Nyc

# %%
df2.head()
# Out:
#   Rating                                            Comment
# 0      3                           🤟🤟🤟 Motorola is the best
# 1      5  🙋🙋HONEST REVIEW 🙋🙋\n1st...Camre click always n...
# 2      5  😱😱6000mah good luck with your friends👭👬 and th...
# 3      5  👍😘😘😘Wow very nice product "Motorola"(Moto G60 ...
# 4      4  🤩😍🥰❤❤❤ very nice phone.... people don't think ...

# %%
df =pd.read_csv("comment1.csv")
df.head()
# Out:
#    Unnamed: 0  Rating                                            Comment
# 0           0       4                         🤩🤩🤩 I am very very happy😊😊
# 1           1       4  👏👏 Delivery service is good 👍\nThis phone is a...
# 2           2       5                                     👌👌good control
# 3           3       4    👌👌👌Very good product I am very happy 👌👌👌 😊😊😊😊😊😊
# 4           4       5                                       💫✨Let it be✨

# %%
df = df.drop(['Unnamed: 0'],axis = 1)

# %%
df.head()
# Out:
#    Rating                                            Comment
# 0       4                         🤩🤩🤩 I am very very happy😊😊
# 1       4  👏👏 Delivery service is good 👍\nThis phone is a...
# 2       5                                     👌👌good control
# 3       4    👌👌👌Very good product I am very happy 👌👌👌 😊😊😊😊😊😊
# 4       5                                       💫✨Let it be✨

# %%
df = df.reset_index(drop=True)
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
data = pd.concat([df, df1,df2], axis=0)

# %%
data
# Out:
#       Rating                                            Comment
# 0          4                         🤩🤩🤩 I am very very happy😊😊
# 1          4  👏👏 Delivery service is good 👍\nThis phone is a...
# 2          5                                     👌👌good control
# 3          4    👌👌👌Very good product I am very happy 👌👌👌 😊😊😊😊😊😊
# 4          5                                       💫✨Let it be✨
# ...      ...                                                ...
# 11389      5                 Best phone go ahead to buy it... 👍
# 11390      5                              Really Nice product..
# 11391      5                Really a great phone from motorola.
# 11392      5  Gets heated a lot. Camera choppy. Does not hav...
# 11393      5               Very nice phone in this price range.
#
# [23970 rows x 2 columns]

# %%
data.to_csv("final-comment-scraping.csv")
